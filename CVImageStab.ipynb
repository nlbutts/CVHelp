# %%
import cv2
import numpy as np

# %%
infile = '/home/nlbutts/Videos/out.mp4'
trim_front = 5
time_back = 1

# %%
cap = cv2.VideoCapture(infile)
n_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
print(f'{w}x{h} total frames: {n_frames} fps: {fps}')
print(cap.isOpened())
# Out:
# 1280x720 total frames: 450 fps: 29.97002997002997
# True

# %%
_, prev = cap.read()
prev_gray = cv2.cvtColor(prev, cv2.COLOR_BGR2GRAY)

# %%
def movingAverage(curve, radius):
  window_size = 2 * radius + 1
  # Define the filter
  f = np.ones(window_size)/window_size
  # Add padding to the boundaries
  curve_pad = np.pad(curve, (radius, radius), 'edge')
  # Apply convolution
  curve_smoothed = np.convolve(curve_pad, f, mode='same')
  # Remove padding
  curve_smoothed = curve_smoothed[radius:-radius]
  # return smoothed curve
  return curve_smoothed

# %%
def smooth(trajectory, SMOOTHING_RADIUS=5):
  smoothed_trajectory = np.copy(trajectory)
  # Filter the x, y and angle curves
  for i in range(3):
    smoothed_trajectory[:,i] = movingAverage(trajectory[:,i], radius=SMOOTHING_RADIUS)

  return smoothed_trajectory

# %%
# Pre-define transformation-store array
transforms = np.zeros((n_frames-1, 3), np.float32)

for i in range(n_frames-2):
  # Detect feature points in previous frame
  prev_pts = cv2.goodFeaturesToTrack(prev_gray,
                                     maxCorners=200,
                                     qualityLevel=0.01,
                                     minDistance=30,
                                     blockSize=3)

  # Read next frame
  success, curr = cap.read()
  if not success:
    break

  # Convert to grayscale
  curr_gray = cv2.cvtColor(curr, cv2.COLOR_BGR2GRAY)

  # Calculate optical flow (i.e. track feature points)
  curr_pts, status, err = cv2.calcOpticalFlowPyrLK(prev_gray, curr_gray, prev_pts, None)

  # Sanity check
  assert prev_pts.shape == curr_pts.shape

  # Filter only valid points
  idx = np.where(status==1)[0]
  prev_pts = prev_pts[idx]
  curr_pts = curr_pts[idx]

  #Find transformation matrix
  #m = cv2.estimateRigidTransform(prev_pts, curr_pts, fullAffine=False) #will only work with OpenCV-3 or less
  m, inliers = cv2.estimateAffine2D(prev_pts, curr_pts)

  # Extract traslation
  dx = m[0,2]
  dy = m[1,2]

  # Extract rotation angle
  da = np.arctan2(m[1,0], m[0,0])

  # Store transformation
  transforms[i] = [dx,dy,da]

  # Move to next frame
  prev_gray = curr_gray

  print("Frame: " + str(i) +  "/" + str(n_frames) + " -  Tracked points : " + str(len(prev_pts)))
# Out:
# Frame: 0/450 -  Tracked points : 196
# Frame: 1/450 -  Tracked points : 200
# Frame: 2/450 -  Tracked points : 198
# Frame: 3/450 -  Tracked points : 196
# Frame: 4/450 -  Tracked points : 198
# Frame: 5/450 -  Tracked points : 200
# Frame: 6/450 -  Tracked points : 200
# Frame: 7/450 -  Tracked points : 198
# Frame: 8/450 -  Tracked points : 194
# Frame: 9/450 -  Tracked points : 198
# Frame: 10/450 -  Tracked points : 198
# Frame: 11/450 -  Tracked points : 198
# Frame: 12/450 -  Tracked points : 199
# Frame: 13/450 -  Tracked points : 198
# Frame: 14/450 -  Tracked points : 199
# Frame: 15/450 -  Tracked points : 199
# Frame: 16/450 -  Tracked points : 200
# Frame: 17/450 -  Tracked points : 199
# Frame: 18/450 -  Tracked points : 197
# Frame: 19/450 -  Tracked points : 196
# Frame: 20/450 -  Tracked points : 199
# Frame: 21/450 -  Tracked points : 193
# Frame: 22/450 -  Tracked points : 198
# Frame: 23/450 -  Tracked points : 198
# Frame: 24/450 -  Tracked points : 199
# Frame: 25/450 -  Tracked points : 200
# Frame: 26/450 -  Tracked points : 200
# Frame: 27/450 -  Tracked points : 200
# Frame: 28/450 -  Tracked points : 198
# Frame: 29/450 -  Tracked points : 198
# Frame: 30/450 -  Tracked points : 199
# Frame: 31/450 -  Tracked points : 199
# Frame: 32/450 -  Tracked points : 200
# Frame: 33/450 -  Tracked points : 200
# Frame: 34/450 -  Tracked points : 200
# Frame: 35/450 -  Tracked points : 199
# Frame: 36/450 -  Tracked points : 199
# Frame: 37/450 -  Tracked points : 198
# Frame: 38/450 -  Tracked points : 199
# Frame: 39/450 -  Tracked points : 197
# Frame: 40/450 -  Tracked points : 199
# Frame: 41/450 -  Tracked points : 200
# Frame: 42/450 -  Tracked points : 200
# Frame: 43/450 -  Tracked points : 200
# Frame: 44/450 -  Tracked points : 200
# Frame: 45/450 -  Tracked points : 200
# Frame: 46/450 -  Tracked points : 200
# Frame: 47/450 -  Tracked points : 200
# Frame: 48/450 -  Tracked points : 200
# Frame: 49/450 -  Tracked points : 200
# Frame: 50/450 -  Tracked points : 200
# Frame: 51/450 -  Tracked points : 200
# Frame: 52/450 -  Tracked points : 200
# Frame: 53/450 -  Tracked points : 196
# Frame: 54/450 -  Tracked points : 198
# Frame: 55/450 -  Tracked points : 196
# Frame: 56/450 -  Tracked points : 197
# Frame: 57/450 -  Tracked points : 196
# Frame: 58/450 -  Tracked points : 198
# Frame: 59/450 -  Tracked points : 199
# Frame: 60/450 -  Tracked points : 200
# Frame: 61/450 -  Tracked points : 200
# Frame: 62/450 -  Tracked points : 199
# Frame: 63/450 -  Tracked points : 200
# Frame: 64/450 -  Tracked points : 195
# Frame: 65/450 -  Tracked points : 200
# Frame: 66/450 -  Tracked points : 198
# Frame: 67/450 -  Tracked points : 198
# Frame: 68/450 -  Tracked points : 200
# Frame: 69/450 -  Tracked points : 200
# Frame: 70/450 -  Tracked points : 199
# Frame: 71/450 -  Tracked points : 200
# Frame: 72/450 -  Tracked points : 200
# Frame: 73/450 -  Tracked points : 200
# Frame: 74/450 -  Tracked points : 200
# Frame: 75/450 -  Tracked points : 199
# Frame: 76/450 -  Tracked points : 200
# Frame: 77/450 -  Tracked points : 199
# Frame: 78/450 -  Tracked points : 196
# Frame: 79/450 -  Tracked points : 198
# Frame: 80/450 -  Tracked points : 199
# Frame: 81/450 -  Tracked points : 190
# Frame: 82/450 -  Tracked points : 191
# Frame: 83/450 -  Tracked points : 193
# Frame: 84/450 -  Tracked points : 199
# Frame: 85/450 -  Tracked points : 199
# Frame: 86/450 -  Tracked points : 198
# Frame: 87/450 -  Tracked points : 199
# Frame: 88/450 -  Tracked points : 200
# Frame: 89/450 -  Tracked points : 199
# Frame: 90/450 -  Tracked points : 198
# Frame: 91/450 -  Tracked points : 198
# Frame: 92/450 -  Tracked points : 195
# Frame: 93/450 -  Tracked points : 200
# Frame: 94/450 -  Tracked points : 192
# Frame: 95/450 -  Tracked points : 197
# Frame: 96/450 -  Tracked points : 196
# Frame: 97/450 -  Tracked points : 197
# Frame: 98/450 -  Tracked points : 196
# Frame: 99/450 -  Tracked points : 195
# Frame: 100/450 -  Tracked points : 197
# Frame: 101/450 -  Tracked points : 197
# Frame: 102/450 -  Tracked points : 197
# Frame: 103/450 -  Tracked points : 200
# Frame: 104/450 -  Tracked points : 199
# Frame: 105/450 -  Tracked points : 198
# Frame: 106/450 -  Tracked points : 197
# Frame: 107/450 -  Tracked points : 198
# Frame: 108/450 -  Tracked points : 198
# Frame: 109/450 -  Tracked points : 199
# Frame: 110/450 -  Tracked points : 200
# Frame: 111/450 -  Tracked points : 200
# Frame: 112/450 -  Tracked points : 200
# Frame: 113/450 -  Tracked points : 200
# Frame: 114/450 -  Tracked points : 200
# Frame: 115/450 -  Tracked points : 200
# Frame: 116/450 -  Tracked points : 199
# Frame: 117/450 -  Tracked points : 200
# Frame: 118/450 -  Tracked points : 199
# Frame: 119/450 -  Tracked points : 200
# Frame: 120/450 -  Tracked points : 200
# Frame: 121/450 -  Tracked points : 199
# Frame: 122/450 -  Tracked points : 199
# Frame: 123/450 -  Tracked points : 199
# Frame: 124/450 -  Tracked points : 200
# Frame: 125/450 -  Tracked points : 200
# Frame: 126/450 -  Tracked points : 200
# Frame: 127/450 -  Tracked points : 200
# Frame: 128/450 -  Tracked points : 200
# Frame: 129/450 -  Tracked points : 200
# Frame: 130/450 -  Tracked points : 200
# Frame: 131/450 -  Tracked points : 197
# Frame: 132/450 -  Tracked points : 199
# Frame: 133/450 -  Tracked points : 200
# Frame: 134/450 -  Tracked points : 198
# Frame: 135/450 -  Tracked points : 200
# Frame: 136/450 -  Tracked points : 200
# Frame: 137/450 -  Tracked points : 200
# Frame: 138/450 -  Tracked points : 200
# Frame: 139/450 -  Tracked points : 200
# Frame: 140/450 -  Tracked points : 199
# Frame: 141/450 -  Tracked points : 200
# Frame: 142/450 -  Tracked points : 200
# Frame: 143/450 -  Tracked points : 200
# Frame: 144/450 -  Tracked points : 200
# Frame: 145/450 -  Tracked points : 199
# Frame: 146/450 -  Tracked points : 198
# Frame: 147/450 -  Tracked points : 199
# Frame: 148/450 -  Tracked points : 199
# Frame: 149/450 -  Tracked points : 200
# Frame: 150/450 -  Tracked points : 200
# Frame: 151/450 -  Tracked points : 199
# Frame: 152/450 -  Tracked points : 197
# Frame: 153/450 -  Tracked points : 197
# Frame: 154/450 -  Tracked points : 192
# Frame: 155/450 -  Tracked points : 197
# Frame: 156/450 -  Tracked points : 200
# Frame: 157/450 -  Tracked points : 200
# Frame: 158/450 -  Tracked points : 197
# Frame: 159/450 -  Tracked points : 200
# Frame: 160/450 -  Tracked points : 200
# Frame: 161/450 -  Tracked points : 199
# Frame: 162/450 -  Tracked points : 199
# Frame: 163/450 -  Tracked points : 199
# Frame: 164/450 -  Tracked points : 200
# Frame: 165/450 -  Tracked points : 200
# Frame: 166/450 -  Tracked points : 200
# Frame: 167/450 -  Tracked points : 200
# Frame: 168/450 -  Tracked points : 200
# Frame: 169/450 -  Tracked points : 198
# Frame: 170/450 -  Tracked points : 199
# Frame: 171/450 -  Tracked points : 200
# Frame: 172/450 -  Tracked points : 200
# Frame: 173/450 -  Tracked points : 200
# Frame: 174/450 -  Tracked points : 199
# Frame: 175/450 -  Tracked points : 200
# Frame: 176/450 -  Tracked points : 200
# Frame: 177/450 -  Tracked points : 200
# Frame: 178/450 -  Tracked points : 200
# Frame: 179/450 -  Tracked points : 200
# Frame: 180/450 -  Tracked points : 200
# Frame: 181/450 -  Tracked points : 199
# Frame: 182/450 -  Tracked points : 200
# Frame: 183/450 -  Tracked points : 200
# Frame: 184/450 -  Tracked points : 199
# Frame: 185/450 -  Tracked points : 200
# Frame: 186/450 -  Tracked points : 199
# Frame: 187/450 -  Tracked points : 200
# Frame: 188/450 -  Tracked points : 200
# Frame: 189/450 -  Tracked points : 200
# Frame: 190/450 -  Tracked points : 199
# Frame: 191/450 -  Tracked points : 200
# Frame: 192/450 -  Tracked points : 198
# Frame: 193/450 -  Tracked points : 198
# Frame: 194/450 -  Tracked points : 200
# Frame: 195/450 -  Tracked points : 200
# Frame: 196/450 -  Tracked points : 200
# Frame: 197/450 -  Tracked points : 199
# Frame: 198/450 -  Tracked points : 199
# Frame: 199/450 -  Tracked points : 198
# Frame: 200/450 -  Tracked points : 200
# Frame: 201/450 -  Tracked points : 200
# Frame: 202/450 -  Tracked points : 200
# Frame: 203/450 -  Tracked points : 199
# Frame: 204/450 -  Tracked points : 200
# Frame: 205/450 -  Tracked points : 200
# Frame: 206/450 -  Tracked points : 200
# Frame: 207/450 -  Tracked points : 200
# Frame: 208/450 -  Tracked points : 200
# Frame: 209/450 -  Tracked points : 200
# Frame: 210/450 -  Tracked points : 200
# Frame: 211/450 -  Tracked points : 200
# Frame: 212/450 -  Tracked points : 200
# Frame: 213/450 -  Tracked points : 200
# Frame: 214/450 -  Tracked points : 200
# Frame: 215/450 -  Tracked points : 200
# Frame: 216/450 -  Tracked points : 200
# Frame: 217/450 -  Tracked points : 200
# Frame: 218/450 -  Tracked points : 200
# Frame: 219/450 -  Tracked points : 199
# Frame: 220/450 -  Tracked points : 199
# Frame: 221/450 -  Tracked points : 198
# Frame: 222/450 -  Tracked points : 198
# Frame: 223/450 -  Tracked points : 199
# Frame: 224/450 -  Tracked points : 200
# Frame: 225/450 -  Tracked points : 200
# Frame: 226/450 -  Tracked points : 200
# Frame: 227/450 -  Tracked points : 200
# Frame: 228/450 -  Tracked points : 200
# Frame: 229/450 -  Tracked points : 200
# Frame: 230/450 -  Tracked points : 200
# Frame: 231/450 -  Tracked points : 200
# Frame: 232/450 -  Tracked points : 200
# Frame: 233/450 -  Tracked points : 200
# Frame: 234/450 -  Tracked points : 199
# Frame: 235/450 -  Tracked points : 199
# Frame: 236/450 -  Tracked points : 199
# Frame: 237/450 -  Tracked points : 199
# Frame: 238/450 -  Tracked points : 200
# Frame: 239/450 -  Tracked points : 200
# Frame: 240/450 -  Tracked points : 200
# Frame: 241/450 -  Tracked points : 200
# Frame: 242/450 -  Tracked points : 200
# Frame: 243/450 -  Tracked points : 198
# Frame: 244/450 -  Tracked points : 195
# Frame: 245/450 -  Tracked points : 198
# Frame: 246/450 -  Tracked points : 200
# Frame: 247/450 -  Tracked points : 200
# Frame: 248/450 -  Tracked points : 199
# Frame: 249/450 -  Tracked points : 199
# Frame: 250/450 -  Tracked points : 199
# Frame: 251/450 -  Tracked points : 199
# Frame: 252/450 -  Tracked points : 199
# Frame: 253/450 -  Tracked points : 200
# Frame: 254/450 -  Tracked points : 200
# Frame: 255/450 -  Tracked points : 200
# Frame: 256/450 -  Tracked points : 200
# Frame: 257/450 -  Tracked points : 200
# Frame: 258/450 -  Tracked points : 200
# Frame: 259/450 -  Tracked points : 200
# Frame: 260/450 -  Tracked points : 200
# Frame: 261/450 -  Tracked points : 200
# Frame: 262/450 -  Tracked points : 200
# Frame: 263/450 -  Tracked points : 200
# Frame: 264/450 -  Tracked points : 200
# Frame: 265/450 -  Tracked points : 195
# Frame: 266/450 -  Tracked points : 200
# Frame: 267/450 -  Tracked points : 198
# Frame: 268/450 -  Tracked points : 200
# Frame: 269/450 -  Tracked points : 199
# Frame: 270/450 -  Tracked points : 195
# Frame: 271/450 -  Tracked points : 197
# Frame: 272/450 -  Tracked points : 197
# Frame: 273/450 -  Tracked points : 200
# Frame: 274/450 -  Tracked points : 200
# Frame: 275/450 -  Tracked points : 200
# Frame: 276/450 -  Tracked points : 199
# Frame: 277/450 -  Tracked points : 199
# Frame: 278/450 -  Tracked points : 200
# Frame: 279/450 -  Tracked points : 200
# Frame: 280/450 -  Tracked points : 200
# Frame: 281/450 -  Tracked points : 200
# Frame: 282/450 -  Tracked points : 200
# Frame: 283/450 -  Tracked points : 197
# Frame: 284/450 -  Tracked points : 197
# Frame: 285/450 -  Tracked points : 196
# Frame: 286/450 -  Tracked points : 200
# Frame: 287/450 -  Tracked points : 200
# Frame: 288/450 -  Tracked points : 200
# Frame: 289/450 -  Tracked points : 199
# Frame: 290/450 -  Tracked points : 200
# Frame: 291/450 -  Tracked points : 200
# Frame: 292/450 -  Tracked points : 199
# Frame: 293/450 -  Tracked points : 200
# Frame: 294/450 -  Tracked points : 199
# Frame: 295/450 -  Tracked points : 200
# Frame: 296/450 -  Tracked points : 198
# Frame: 297/450 -  Tracked points : 198
# Frame: 298/450 -  Tracked points : 200
# Frame: 299/450 -  Tracked points : 200
# Frame: 300/450 -  Tracked points : 200
# Frame: 301/450 -  Tracked points : 200
# Frame: 302/450 -  Tracked points : 200
# Frame: 303/450 -  Tracked points : 200
# Frame: 304/450 -  Tracked points : 200
# Frame: 305/450 -  Tracked points : 200
# Frame: 306/450 -  Tracked points : 199
# Frame: 307/450 -  Tracked points : 200
# Frame: 308/450 -  Tracked points : 200
# Frame: 309/450 -  Tracked points : 200
# Frame: 310/450 -  Tracked points : 200
# Frame: 311/450 -  Tracked points : 200
# Frame: 312/450 -  Tracked points : 200
# Frame: 313/450 -  Tracked points : 200
# Frame: 314/450 -  Tracked points : 200
# Frame: 315/450 -  Tracked points : 200
# Frame: 316/450 -  Tracked points : 196
# Frame: 317/450 -  Tracked points : 197
# Frame: 318/450 -  Tracked points : 199
# Frame: 319/450 -  Tracked points : 198
# Frame: 320/450 -  Tracked points : 199
# Frame: 321/450 -  Tracked points : 200
# Frame: 322/450 -  Tracked points : 200
# Frame: 323/450 -  Tracked points : 200
# Frame: 324/450 -  Tracked points : 200
# Frame: 325/450 -  Tracked points : 200
# Frame: 326/450 -  Tracked points : 200
# Frame: 327/450 -  Tracked points : 200
# Frame: 328/450 -  Tracked points : 197
# Frame: 329/450 -  Tracked points : 195
# Frame: 330/450 -  Tracked points : 198
# Frame: 331/450 -  Tracked points : 200
# Frame: 332/450 -  Tracked points : 200
# Frame: 333/450 -  Tracked points : 199
# Frame: 334/450 -  Tracked points : 199
# Frame: 335/450 -  Tracked points : 200
# Frame: 336/450 -  Tracked points : 199
# Frame: 337/450 -  Tracked points : 199
# Frame: 338/450 -  Tracked points : 200
# Frame: 339/450 -  Tracked points : 200
# Frame: 340/450 -  Tracked points : 199
# Frame: 341/450 -  Tracked points : 198
# Frame: 342/450 -  Tracked points : 199
# Frame: 343/450 -  Tracked points : 200
# Frame: 344/450 -  Tracked points : 199
# Frame: 345/450 -  Tracked points : 200
# Frame: 346/450 -  Tracked points : 200
# Frame: 347/450 -  Tracked points : 200
# Frame: 348/450 -  Tracked points : 200
# Frame: 349/450 -  Tracked points : 200
# Frame: 350/450 -  Tracked points : 199
# Frame: 351/450 -  Tracked points : 198
# Frame: 352/450 -  Tracked points : 200
# Frame: 353/450 -  Tracked points : 200
# Frame: 354/450 -  Tracked points : 200
# Frame: 355/450 -  Tracked points : 199
# Frame: 356/450 -  Tracked points : 199
# Frame: 357/450 -  Tracked points : 199
# Frame: 358/450 -  Tracked points : 198
# Frame: 359/450 -  Tracked points : 200
# Frame: 360/450 -  Tracked points : 200
# Frame: 361/450 -  Tracked points : 200
# Frame: 362/450 -  Tracked points : 200
# Frame: 363/450 -  Tracked points : 200
# Frame: 364/450 -  Tracked points : 199
# Frame: 365/450 -  Tracked points : 200
# Frame: 366/450 -  Tracked points : 200
# Frame: 367/450 -  Tracked points : 199
# Frame: 368/450 -  Tracked points : 198
# Frame: 369/450 -  Tracked points : 200
# Frame: 370/450 -  Tracked points : 199
# Frame: 371/450 -  Tracked points : 200
# Frame: 372/450 -  Tracked points : 200
# Frame: 373/450 -  Tracked points : 200
# Frame: 374/450 -  Tracked points : 200
# Frame: 375/450 -  Tracked points : 200
# Frame: 376/450 -  Tracked points : 200
# Frame: 377/450 -  Tracked points : 198
# Frame: 378/450 -  Tracked points : 198
# Frame: 379/450 -  Tracked points : 199
# Frame: 380/450 -  Tracked points : 199
# Frame: 381/450 -  Tracked points : 198
# Frame: 382/450 -  Tracked points : 196
# Frame: 383/450 -  Tracked points : 198
# Frame: 384/450 -  Tracked points : 200
# Frame: 385/450 -  Tracked points : 200
# Frame: 386/450 -  Tracked points : 200
# Frame: 387/450 -  Tracked points : 200
# Frame: 388/450 -  Tracked points : 200
# Frame: 389/450 -  Tracked points : 200
# Frame: 390/450 -  Tracked points : 200
# Frame: 391/450 -  Tracked points : 200
# Frame: 392/450 -  Tracked points : 200
# Frame: 393/450 -  Tracked points : 200
# Frame: 394/450 -  Tracked points : 200
# Frame: 395/450 -  Tracked points : 200
# Frame: 396/450 -  Tracked points : 200
# Frame: 397/450 -  Tracked points : 200
# Frame: 398/450 -  Tracked points : 200
# Frame: 399/450 -  Tracked points : 199
# Frame: 400/450 -  Tracked points : 200
# Frame: 401/450 -  Tracked points : 200
# Frame: 402/450 -  Tracked points : 200
# Frame: 403/450 -  Tracked points : 200
# Frame: 404/450 -  Tracked points : 199
# Frame: 405/450 -  Tracked points : 199
# Frame: 406/450 -  Tracked points : 200
# Frame: 407/450 -  Tracked points : 199
# Frame: 408/450 -  Tracked points : 198
# Frame: 409/450 -  Tracked points : 200
# Frame: 410/450 -  Tracked points : 200
# Frame: 411/450 -  Tracked points : 200
# Frame: 412/450 -  Tracked points : 200
# Frame: 413/450 -  Tracked points : 200
# Frame: 414/450 -  Tracked points : 200
# Frame: 415/450 -  Tracked points : 200
# Frame: 416/450 -  Tracked points : 200
# Frame: 417/450 -  Tracked points : 200
# Frame: 418/450 -  Tracked points : 200
# Frame: 419/450 -  Tracked points : 200
# Frame: 420/450 -  Tracked points : 200
# Frame: 421/450 -  Tracked points : 200
# Frame: 422/450 -  Tracked points : 200
# Frame: 423/450 -  Tracked points : 200
# Frame: 424/450 -  Tracked points : 200
# Frame: 425/450 -  Tracked points : 199
# Frame: 426/450 -  Tracked points : 200
# Frame: 427/450 -  Tracked points : 200
# Frame: 428/450 -  Tracked points : 200
# Frame: 429/450 -  Tracked points : 200
# Frame: 430/450 -  Tracked points : 200
# Frame: 431/450 -  Tracked points : 200
# Frame: 432/450 -  Tracked points : 199
# Frame: 433/450 -  Tracked points : 198
# Frame: 434/450 -  Tracked points : 200
# Frame: 435/450 -  Tracked points : 199
# Frame: 436/450 -  Tracked points : 199
# Frame: 437/450 -  Tracked points : 200
# Frame: 438/450 -  Tracked points : 200
# Frame: 439/450 -  Tracked points : 200
# Frame: 440/450 -  Tracked points : 200
# Frame: 441/450 -  Tracked points : 200
# Frame: 442/450 -  Tracked points : 200
# Frame: 443/450 -  Tracked points : 200
# Frame: 444/450 -  Tracked points : 200
# Frame: 445/450 -  Tracked points : 200
# Frame: 446/450 -  Tracked points : 200
# Frame: 447/450 -  Tracked points : 200

# %%
# Compute trajectory using cumulative sum of transformations
trajectory = np.cumsum(transforms, axis=0)
smoothed_trajectory = smooth(trajectory, 50)

# %%
# Calculate difference in smoothed_trajectory and trajectory
difference = smoothed_trajectory - trajectory

# Calculate newer transformation array
transforms_smooth = transforms + difference

# %%
def fixBorder(frame):
  s = frame.shape
  # Scale the image 4% without moving the center
  T = cv2.getRotationMatrix2D((s[1]/2, s[0]/2), 0, 1.04)
  frame = cv2.warpAffine(frame, T, (s[1], s[0]))
  return frame

# %%
# Reset stream to first frame
cap.set(cv2.CAP_PROP_POS_FRAMES, 0)

fourcc = cv2.VideoWriter_fourcc(*'yuv4')
out = cv2.VideoWriter('video_out.mkv', fourcc, fps, (w,h))

# Write n_frames-1 transformed frames
for i in range(n_frames-2):
  # Read next frame
  success, frame = cap.read()
  if not success:
    break

  # Extract transformations from the new transformation array
  dx = transforms_smooth[i,0]
  dy = transforms_smooth[i,1]
  da = transforms_smooth[i,2]

  # Reconstruct transformation matrix accordingly to new values
  m = np.zeros((2,3), np.float32)
  m[0,0] = np.cos(da)
  m[0,1] = -np.sin(da)
  m[1,0] = np.sin(da)
  m[1,1] = np.cos(da)
  m[0,2] = dx
  m[1,2] = dy

  # Apply affine wrapping to the given frame
  frame_stabilized = cv2.warpAffine(frame, m, (w,h))

  # Fix border artifacts
  frame_stabilized = fixBorder(frame_stabilized)

  # Write the frame to the file
  frame_out = cv2.hconcat([frame, frame_stabilized])

  # If the image is too big, resize it.
  if(frame_out.shape[1] > w):
    frame_out = cv2.resize(frame_out, (frame_out.shape[1]//2, frame_out.shape[0]//2))

  cv2.imshow("Before and After", frame_out)
  cv2.waitKey(10)
  out.write(frame_stabilized)

cv2.destroyAllWindows()
out.release()

# %%
print(frame_stabilized.shape)
# Out:
# (720, 1280, 3)
